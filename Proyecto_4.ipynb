# %% [markdown]
# # ¡Hola Mario!
#
# Mi nombre es Ezequiel Ferrario, soy code reviewer en Tripleten y tengo el agrado de revisar el proyecto que entregaste.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. En un trabajo real, el líder de tu equipo hará una dinámica similar. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Encontrarás mis comentarios más abajo - **por favor, no los muevas, no los modifiques ni los borres**.
#
# ¿Cómo lo voy a hacer? Voy a leer detenidamente cada una de las implementaciones que has llevado a cabo para cumplir con lo solicitado. Verás los comentarios de esta forma:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si todo está perfecto.
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta. Se aceptan uno o dos comentarios de este tipo en el borrador, pero si hay más, deberá hacer las correcciones. Es como una tarea de prueba al solicitar un trabajo: muchos pequeños errores pueden hacer que un candidato sea rechazado.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Hola, muchas gracias por tus comentarios y la revisión.
# </div>
#
# ¡Empecemos!

# %% [markdown]
# --------------
#
#
# <div class="alert alert-block alert-danger">
# <b>Comentario general #1</b> <a class="tocSkip"></a>
#
# Mario, has realizado un excelente proyecto donde practicamente no hay correcciones para hacer.
#
# Me gusto mucho como abordaste todo el proyecto a nivel analisis, ya que en cada punto dejaste un comentario aclaratorio que aporto claridad a todo el trabajo.
#
# A nivel codigo lo optimizaste en cada punto y asi te manejaste excelente en cada seccion.
#
# Resta la conclusion general y con eso este gran proyecto quedara aprobado.
#
# Quedo a la espera de tu correccion, saludos.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario general #2</b> <a class="tocSkip"></a>
#
# Mario, las correcciones fueron muy buenas y la conclusion general excelente.
#
#   Por lo tanto, este proyecto queda **aprobado**.
#
#   Exitos en lo que viene, saludos..</div>
#
# ----------

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
import pandas as pd  
from matplotlib import pyplot as plt
import numpy as np # importar librerías

# %%
instacart_orders= pd.read_csv('/datasets/instacart_orders.csv',sep=';')
products = pd.read_csv('/datasets/products.csv',sep=";")
aisles = pd.read_csv('/datasets/aisles.csv',sep=";")
departments = pd.read_csv('/datasets/departments.csv',sep=";")
order_products= pd.read_csv('/datasets/order_products.csv',sep=";")
# leer conjuntos de datos en los DataFrames

# %%
instacart_orders.info() # mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
products.info() # mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
aisles.info() # mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
departments.info() # mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
order_products.info(show_counts=True) # mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
#
# 1) En los archivos como se menciono hay duplicados que pueden ser duplicados explicitos e implicitos
# 2) En el archivo de instacart_orders hay valores nulos que pueden estropear el analisis en la columna days_since_prior_order
# 3) En products_info igual hay valores ausentes en lo que son el nombre del producto que se tendria que revisar si son productos que hay que borrar como duplicados probablemente o llamar como producto desconocido ya que se olvido poner el nombre.
# 4) En archivo ailes no hay valores ausentes.
# 5) En archivo departmens tampoco hay valores ausentes.
# 6) En archivo order_products hay valores ausentes en add_to_cart_number y el tipo de dato es float64, si es consecutivo en el numero del carrito deberia de ser int64.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buenas conclusiones.</div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# # Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
# 1) Revisar los valores de cada uno de los archivos y ver si todas las columnas que son ID son valores enteros (int64).
# 2) Despues eliminar los valores duplicados explicitos e implicitos para tomar una mejor decision en los datos y tener la informacion limpia, al explorar cada uno de los archivos llamando duplicated para ver cuales son los duplicados y si son por el nombre o ID.
# 3) Revisar los nombres que no tengan diferente nomenclatura como nombre en minusculas y otros en mayusculas ya que pueden ser el mismo producto pero lo detectan como uno nuevo.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `instacart_orders` data frame

# %%
print(instacart_orders['order_id'].duplicated().sum())
print("")
print(instacart_orders[instacart_orders['order_id'].duplicated()])
# Revisa si hay pedidos duplicados
# Out:
# 15
#
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?

# %%
# Basándote en tus hallazgos,
miercoles_duplicados = instacart_orders[(instacart_orders["order_dow"]==3) & (instacart_orders['order_hour_of_day']==2)] # Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
print(miercoles_duplicados)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?

# %%
instacart_orders.drop_duplicates(inplace=True)# Elimina los pedidos duplicados

# %%
print(instacart_orders.duplicated().sum())# Vuelve a verificar si hay filas duplicadas
# Out:
# 0

# %%
print(instacart_orders['order_id'].duplicated().sum())# Vuelve a verificar si hay IDs duplicados de pedidos
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# Se detectaron que los datos duplicados se encontraban con el dia dow ==3 y order_hour_of_day ==2 lo cual significa que paso algo a esa hora, talvez un servidor se cayo o simplemente la persona duplico las ordenes por error.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Perfecto, muy bien detectado los duplicados.</div>

# %% [markdown]
# ### `products` data frame

# %%
print(products.duplicated().sum())# Verifica si hay filas totalmente duplicadas
# Out:
# 0

# %%
print(products['product_id'].duplicated().sum())# Verifica si hay IDs duplicadas de productos
# Out:
# 0

# %%
print(products['product_name'].str.upper().duplicated().sum())
print('')
print(products[products['product_name'].str.upper().duplicated()])# Revisa si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
# Out:
# 1361
#
#        product_id                                     product_name  aisle_id  \
# 71             72                                              NaN       100
# 109           110                                              NaN       100
# 296           297                                              NaN       100
# 416           417                                              NaN       100
# 436           437                                              NaN       100
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# ...

# %%
print(products['product_name'].isna().duplicated().sum())
print('')
print(products[products['product_name'].isna()])# Revisa si hay nombres duplicados de productos no faltantes
# Out:
# 49692
#
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# 1) Se vio que los valores ausentes se encuentran en la columna product_name que tienen en comun que son de la aisle_id 100 y del department_id 21, los cuales se tienen que reemplazar posteriormente.
# 2) Se observo tambien que al contar los valores ausentes se tienen 49692 valores ausentes pero al momento de desplegarlos son solo 1258 valores ausentes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien entendiendo la naturaleza de los duplicados.</div>

# %% [markdown]
# ### `departments` data frame

# %%
print(departments.duplicated().sum())# Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
print(departments['department_id'].duplicated().sum())# Revisa si hay IDs duplicadas de productos
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# 1) En este caso no hay valores duplicados en cuanto a filas en el data frame de departamentos y tampoco hay id de departamentos duplicados, por lo que esta correcto este data frame.

# %% [markdown]
# ### `aisles` data frame

# %%
print(aisles.duplicated().sum())# Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
print(aisles['aisle_id'].duplicated().sum())# Revisa si hay IDs duplicadas de productos
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# 1) En este caso no hay valore duplicados en el data frame de aisles y tampoco duplicados en el aisles id, por lo cual este data frame esta correcto

# %% [markdown]
# ### `order_products` data frame

# %%
print(order_products.duplicated().sum())# Revisa si hay filas totalmente duplicadas
# Out:
# 0

# %%
print('Order_ID duplicados')
print(order_products['order_id'].duplicated().sum())
print('')
print('Product_ID duplicados')
print(order_products['product_id'].duplicated().sum())
print('')
print('Add to cart order duplicados')
print(order_products['add_to_cart_order'].duplicated().sum())
print('')
print('Reordered duplicados')
print(order_products['reordered'].duplicated().sum())# Vuelve a verificar si hay cualquier otro duplicado engañoso
# Out:
# Order_ID duplicados
# 4094961
#
# Product_ID duplicados
# 4499434
#
# Add to cart order duplicados
# 4544942
#
# Reordered duplicados
# 4545005

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# 1) Existen duplicados en las columnas de orderid, product id, add to cart y reordered pero no afectan por la naturaleza de las ordenes, son columnas que se pueden duplicar por pedidos diferentes o el mismo pedido pero diferente producto.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buena seccion.</div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
print(products['product_name'].isna().sum())
print('')
print(products[products['product_name'].isna()])# Encuentra los valores ausentes en la columna 'product_name'
# Out:
# 1258
#
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# 1) Hay 1258 valores ausentes en la columna product_name

# %%
print(products[products['product_name'].isna()])#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
# si los valores ausentes se encuentran en la aisle 100 pasillo department id 21
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# 1) Los valores ausentes se encuentran en la isla 100 departamento 21, como se puede osbervar anteriormente.

# %%
print(products[products['product_name'].isna()])# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# 1) Si los productos son dupicados en esa isla y departamento.

# %%
print(departments[departments['department_id']==21])
print('')
print(aisles[aisles['aisle_id']==100])# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
# Out:
#     department_id department
# 20             21    missing
#
#     aisle_id    aisle
# 99       100  missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# 1) Los valores de los departamentos 21 y de la aisle 100 son missing por lo cual el producto tambien es NaN.

# %%
products['product_name']=products['product_name'].fillna('unknown')
print(products['product_name'].isna().sum())# Completa los nombres de productos ausentes con 'Unknown'
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buen manejo de nulos.</div>

# %% [markdown]
# ### `orders` data frame

# %%
print(instacart_orders[instacart_orders['days_since_prior_order'].isna()])# Encuentra los valores ausentes
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# 478926   2499542    68810             1          4                 19
# 478945   1387033    22496             1          5                 14
#
#         days_since_prior_order
# 28                         NaN
# 96                         NaN
# ...

# %%
print(instacart_orders[(instacart_orders['order_number']>1) & (instacart_orders['days_since_prior_order']=='NaN')])# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# 1) Todas los valores ausentes de days_since_prior_order son relacionados a la 1 orden del cliente, ya que como no hay orden anterior por eso es NaN, tiene sentido por la naturaleza de la columna

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Perfecto entendiendo los nulos de este dataset.</div>

# %% [markdown]
# ### `order_products` data frame

# %%
print(order_products['add_to_cart_order'].isna().sum()) # Encuentra los valores ausentes
# Out:
# 836

# %%
print('Numero minimo')
print(order_products['add_to_cart_order'].min())
print('')
print('Numero maximo')
print(order_products['add_to_cart_order'].max()) # ¿Cuáles son los valores mínimos y máximos en esta columna?
# Out:
# Numero minimo
# 1.0
#
# Numero maximo
# 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# 1) Hay un rango en add to cart order que es de 1 a 64.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'

#1 obtenemos primero las ordenes que tienen add to cart order como valor ausente
ordenes_ausentes=order_products[order_products['add_to_cart_order'].isna()]

#2 obtenemos las ordenes ausentes del filtrado que realizamos anteriormente.
id_ordenes_ausentes=ordenes_ausentes['order_id']

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo

#1 Se filtran las ordenes que tienen mayores de 64 productos.
ordenes_mayores_64=order_products[order_products['order_id'].isin(id_ordenes_ausentes)]

#2 Se agrupan todos los pedidos
ordenes_mayores_64=ordenes_mayores_64.groupby('order_id')['product_id'].count().sort_values()

print(ordenes_mayores_64)
# Out:
# order_id
# 9310        65
# 747668      65
# 1598369     65
# 1677118     65
# 2170451     65
#           ...
# 1959075     98
# 171934     104
# 2136777    108
# 3308010    115
# 61355      127
# Name: product_id, Length: 70, dtype: int64

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# 1) Si existen pedidos de mas de 64 productos que tienen valores ausentes.

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
order_products['add_to_cart_order']=order_products['add_to_cart_order'].fillna(999)

order_products['add_to_cart_order']=order_products['add_to_cart_order'].astype('int')

order_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 138.7 MB

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# 1) Se encontraron muchos valores ausentes en add_to_cart_order los cuales se reemplazaron por 999 y se cambio la columna a entero ya que son numeros consecutivos no hay necesidad de tener flotantes.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¿Por que crees que el maximo de `add_to_cart_order` se detiene en 64? ¿No crees que es un valor muy arbitrario?</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, en este caso es muy probable que se haya almacenado como int64 por lo que se limito a solo ese numero -como maximo-, comentarle este tipo de problemas al cliente hara que nuestros datos sean mas completos.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Se puede detener en 64 ya que puede ser el maximo de la canasta que permite el mercado en linea o lo permitido por cliente, esto para dar oportunidad a mas clientes de obtener los productos, puede ser una estrategia de la propia empresa.
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
#
#  1) Ya se limpiaron los datos lo cual fue algo un poco retador y se vieron algunas tendencias como datos austentes y la cantidad de productos que se tenian en los carritos que son de 65 hacia arriba.
#  2) Se borraron duplicados en lo que son algunas columnas.
#  3) Se tienen los archivos mas limpios para manejar informacion y poder realizar a analisis mas confiables.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buenas conclusiones.</div>

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
# Se verifican primero que 'order_hour_of_day' sea entre 0 y 23 y 'order_dow' que sea entre 0 y 6 que son los dias de la semana y las horas

hora_ordenes=instacart_orders[(instacart_orders['order_hour_of_day'] > 23) & (instacart_orders['order_hour_of_day']<0)]

print(hora_ordenes)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
dias_semana= instacart_orders[(instacart_orders['order_dow']<0) & (instacart_orders['order_dow']>6)]
print(dias_semana)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# Escribe aquí tus conclusiones
#
# 1) Las horas de los dias oscilan entre 0 y 23.
# 2) Los dias de la semana tambien se encuentran entre 0 y 6.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien.</div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
pedidos_hora=instacart_orders.groupby('order_hour_of_day')['user_id'].count()

pedidos_hora.plot(kind='bar',
                    ylabel = 'Numero de personas',
                    xlabel = 'hora',
                    x= 'order_hour_of_day',
                    y= 'pedidos_hora',
                    title='Cantidad de personas que hacen un pedido')

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# 1) Se observa que las personas hacen una mayor cantidad de pedidos entre las 10-11 am y las 2-3 pm de la tarde, se puede ver que empiezan las ventas agresivas desde las 10 de la tarde y empiezan a bajar a las 5 pm.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buen grafico.</div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
ordenes_por_dia=instacart_orders.groupby('order_dow')['user_id'].count()

print('Cantidad de usuarios que hacen sus compras')
print(ordenes_por_dia)

ordenes_por_dia.plot(xlabel='Dias de la semana',
                  ylabel='Cantidad de compras de las personas',
                 x= 'order_dow',
                 y= 'ordenes_por_dia',
                 title='Pedidos a la semana',
                 rot=45,
                 kind='bar')

plt.show()
# Out:
# Cantidad de usuarios que hacen sus compras
# order_dow
# 0    84090
# 1    82185
# 2    65833
# 3    60897
# 4    59810
# 5    63488
# 6    62649
# Name: user_id, dtype: int64

# %% [markdown]
# Escribe aquí tus conclusiones
# 1) Los pedidos ocurren en su mayor cantidad los dias domingo y lunes que son los inicios de semana.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Perfecto.</div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
tiempo_espera=instacart_orders['days_since_prior_order'].value_counts().sort_index()

print('Tiempo de espera minimo',tiempo_espera.min())
print('Tiempo de espera maximo',tiempo_espera.max())
# Out:
# Tiempo de espera minimo 2640
# Tiempo de espera maximo 51337

# %%
tiempo_espera.plot(kind='bar',
                   title='Tiempo de espera de las personas',
                   xlabel='Tiempo de espera en dias',
                   ylabel='Cantidad de personas')

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se obsera que el tiempo de espera de los clientes es de 30 dias y otros cuantos esperan 7 dias siendo estos los valores mas altos.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¿Los dias entre pedidos que tienen 0 a que corresponderia?
#
# ¿Porque crees la razon en que estan concentrados los mayores datos en que se piden cada siete dias? .
#
# Responder este tipo de preguntas robustecen nuestro proyecto y le dan valor a nuestro rol de analista.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Los tiempos de personas que esperan 0 dias, se puede atribuir a productos que son comida por ejemplo o son pequenos en cuanto a tamano por lo que se acaban en el mismo dia y se vuelven a comprar.
#
# Tambien se ve un patron en los dias 7 y 8 que son semanas completas, en los que se ve un patron posterior como si fuera columpio en el que se vuelven a incrementar las ordenes al paso de este tiempo, ya que cada semana se hace el supermercado para poder alimentarse cada uno o tener el reempazo de los productos previamente comprados.
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
#Se filtran unicamente las ordenes de los dias miercoles y sabado (dow=3 y dow=6)

ordenes_miercoles = instacart_orders['order_dow']==3

ordenes_sabado = instacart_orders['order_dow']==6

# %%
#Se cuentan las ordenes que se tienen una vez ya filtradas por los dias por la columna order hour of day para cada uno de los dias

contar_ordenes_miercoles=instacart_orders[ordenes_miercoles]['order_hour_of_day'].value_counts().sort_index()
contar_ordenes_sabado=instacart_orders[ordenes_sabado]['order_hour_of_day'].value_counts().sort_index()

# %%
contar_ordenes_miercoles
# Out:
# 0      373
# 1      215
# 2      106
# 3      101
# 4      108
# 5      170
# 6      643
# 7     1732
# 8     3125
# 9     4490
# 10    5026
# 11    5004
# 12    4688
# 13    4674
# 14    4774
# 15    5163
# 16    4976
# 17    4175
# 18    3463
# 19    2652
# 20    1917
# 21    1450
# 22    1154
# 23     718
# Name: order_hour_of_day, dtype: int64

# %%
contar_ordenes_sabado
# Out:
# 0      464
# 1      254
# 2      177
# 3      125
# 4      118
# 5      161
# 6      451
# 7     1619
# 8     3246
# 9     4311
# 10    4919
# 11    5116
# 12    5132
# 13    5323
# 14    5375
# 15    5188
# 16    5029
# 17    4295
# 18    3338
# 19    2610
# 20    1847
# 21    1473
# 22    1185
# 23     893
# Name: order_hour_of_day, dtype: int64

# %%
total_ordenes_miercoles_sabado=pd.concat([contar_ordenes_miercoles,contar_ordenes_sabado],axis=1)

total_ordenes_miercoles_sabado.columns=['Miercoles','Sabado']

total_ordenes_miercoles_sabado.plot(kind='bar',title='Ordenes por hora del Miercoles y Sabado',xlabel='Horas del dia', ylabel='Cantidad de ordenes',rot=45)\

plt.show()

# %% [markdown]
# Se observa que existe una gran diferencia entre los dias miercoles y sabado en los horarios de 12-14 hay una significativa comparando esos dias.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente grafico, recorda hacer este tipo de analisis en formato **markdown**.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
distribucion_ordenes=instacart_orders.groupby('user_id')['order_id'].count()
print(distribucion_ordenes)
# Out:
# user_id
# 2         2
# 4         2
# 5         1
# 6         2
# 7         2
#          ..
# 206203    1
# 206206    7
# 206207    5
# 206208    9
# 206209    2
# Name: order_id, Length: 157437, dtype: int64

# %%
distribucion_ordenes.plot(kind='hist',bins=20,xlabel='Cantidad de ordenes',title='Pedidos por cliente')

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se observa que la mayor cantidad de personas solo compran entre 1 y 5 veces, esto significa que no hay un enganche de la empresa con los clientes ya que no compran muchos productos o recompran.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien.</div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
filtro_product_name=order_products.merge(products, on='product_id')
productos_mas_populares=filtro_product_name.groupby(['product_id','product_name'])['order_id'].count().sort_values(ascending=False)

# %%
productos_mas_populares.head(20)
# Out:
# product_id  product_name
# 24852       Banana                      66050
# 13176       Bag of Organic Bananas      53297
# 21137       Organic Strawberries        37039
# 21903       Organic Baby Spinach        33971
# 47209       Organic Hass Avocado        29773
# 47766       Organic Avocado             24689
# 47626       Large Lemon                 21495
# 16797       Strawberries                20018
# 26209       Limes                       19690
# 27845       Organic Whole Milk          19600
# 27966       Organic Raspberries         19197
# 22935       Organic Yellow Onion        15898
# 24964       Organic Garlic              15292
# 45007       Organic Zucchini            14584
# 39275       Organic Blueberries         13879
# 49683       Cucumber Kirby              13675
# 28204       Organic Fuji Apple          12544
# 5876        Organic Lemon               12232
# 8277        Apple Honeycrisp Organic    11993
# 40706       Organic Grape Tomatoes      11781
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %%
grafica_productos_mas_populares=productos_mas_populares.head(20)

grafica_productos_mas_populares.plot(kind='bar',title='Top 20 productos mas vendidos',
                                    xlabel='Productd id y Product name',
                                    ylabel='Cantidad de veces que se compro')

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se puede observar en la tabla anterior que el producto que mas se vende en ordenes de los clientes son las bananas en top 1 y la bolsa de bananas organicas como top 2.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
filtro_product_name.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4545007 entries, 0 to 4545006
# Data columns (total 7 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
#  4   product_name       object
#  5   aisle_id           int64
#  6   department_id      int64
# dtypes: int64(6), object(1)
# memory usage: 277.4+ MB

# %%
compra_productos=filtro_product_name.groupby('order_id')['product_id'].count()

# %%
compra_productos.plot(kind='hist',bins=25,title='Cantidad de articulos por pedido')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Esta perfecto el grafico, como consejo podrias graficar  (en otra celda) el top 30 o 40 para visualizar mejor los datos ya que a partir de alli practicamente no tenemos informacion.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %%
compra_productos=filtro_product_name.groupby('order_id')['product_id'].count().head(40)

compra_productos.plot(kind='hist',bins=25,title='Cantidad de articulos por pedido')

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Como podemos observar la mayor cantidad de articulos que se piden son de 1-5 articulos aproximadamente, y disminuye la frecuencia con mayor cantidad de articulos en las diferentes ordenes, posteriormente al momento de colocar mas productos top 30 y 40 vemos que la tendencia es a la baja las personas ya no compran tantos articulos.

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
filtro_product_name.groupby(['product_id','product_name'])['reordered'].sum().sort_values(ascending=False).head(20)
# Out:
# product_id  product_name
# 24852       Banana                      55763
# 13176       Bag of Organic Bananas      44450
# 21137       Organic Strawberries        28639
# 21903       Organic Baby Spinach        26233
# 47209       Organic Hass Avocado        23629
# 47766       Organic Avocado             18743
# 27845       Organic Whole Milk          16251
# 47626       Large Lemon                 15044
# 27966       Organic Raspberries         14748
# 16797       Strawberries                13945
# 26209       Limes                       13327
# 22935       Organic Yellow Onion        11145
# 24964       Organic Garlic              10411
# 45007       Organic Zucchini            10076
# 49683       Cucumber Kirby               9538
# 28204       Organic Fuji Apple           8989
# 8277        Apple Honeycrisp Organic     8836
# 39275       Organic Blueberries          8799
# 5876        Organic Lemon                8412
# 49235       Organic Half & Half          8389
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %%
grafico_top20_mayor_recurrencia=filtro_product_name.groupby(['product_id','product_name'])['reordered'].sum().sort_values(ascending=False).head(20)

grafico_top20_mayor_recurrencia.plot(kind='bar',title='Top 20 productos mas recurrentes en compras',
                                    ylabel='Cantidad de veces que se vuelven a comprar',
                                    xlabel='Product ID y Product Name')

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Aqui podemos observar que el producto que mas se ordena son las bananas que como vimos en la grafica anterior es el mas popular, hace sentido con los productos que mas se ordenan.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
filtro_product_name.groupby(['product_id','product_name'])['reordered'].mean().sort_index().head(20)
# Out:
# product_id  product_name
# 1           Chocolate Sandwich Cookies                                           0.564286
# 2           All-Seasons Salt                                                     0.000000
# 3           Robust Golden Unsweetened Oolong Tea                                 0.738095
# 4           Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce    0.510204
# 7           Pure Coconut Water With Orange                                       0.500000
# 8           Cut Russet Potatoes Steam N' Mash                                    0.315789
# 9           Light Strawberry Blueberry Yogurt                                    0.761905
# 10          Sparkling Orange Juice & Prickly Pear Beverage                       0.448071
# 11          Peach Mango Juice                                                    0.625000
# 12          Chocolate Fudge Layer Cake                                           0.390244
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los primeros productos o id como podemos observar en la tabla no tienen tanta frecuencia de pedidos, lo que significa que no se vuelven a pedir una vez ya pedidos, por lo que el ratio es menor que 1, incluso hay unos que son 0 por ejemplo Dog treats con id 21.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente.</div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
pedidos_clientes=order_products.merge(instacart_orders, on='order_id')

# %%
pedidos_clientes.groupby('user_id')['reordered'].mean().sort_values(ascending=False).head(30)
# Out:
# user_id
# 137587    1.0
# 173474    1.0
# 13918     1.0
# 62300     1.0
# 62307     1.0
# 96301     1.0
# 62312     1.0
# 48616     1.0
# 62316     1.0
# 191162    1.0
# 96310     1.0
# 135349    1.0
# 96321     1.0
# 42811     1.0
# 74363     1.0
# 135307    1.0
# 32600     1.0
# 32597     1.0
# 96349     1.0
# 62327     1.0
# 13962     1.0
# 96300     1.0
# 32614     1.0
# 13911     1.0
# 32633     1.0
# 198284    1.0
# 62213     1.0
# 13844     1.0
# 135533    1.0
# 74382     1.0
# Name: reordered, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Perfecto, bien simplificado el codigo.</div>

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Podemos ver en la tabla anterior que hay 30 clientes que vuelven a pedir el mismo articulo en sus compras, esto es bueno para el negocio ya que son ganancias de clientes leales.

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
primera_vez_ordenandolo=filtro_product_name[filtro_product_name['add_to_cart_order']==1]

# %%
veinte_principales_articulos=primera_vez_ordenandolo.groupby(['product_id','product_name'])['add_to_cart_order'].count().sort_values(ascending=False).head(20)

# %%
veinte_principales_articulos
# Out:
# product_id  product_name
# 24852       Banana                         15562
# 13176       Bag of Organic Bananas         11026
# 27845       Organic Whole Milk              4363
# 21137       Organic Strawberries            3946
# 47209       Organic Hass Avocado            3390
# 21903       Organic Baby Spinach            3336
# 47766       Organic Avocado                 3044
# 19660       Spring Water                    2336
# 16797       Strawberries                    2308
# 27966       Organic Raspberries             2024
# 44632       Sparkling Water Grapefruit      1914
# 49235       Organic Half & Half             1797
# 47626       Large Lemon                     1737
# 196         Soda                            1733
# 38689       Organic Reduced Fat Milk        1397
# 26209       Limes                           1370
# 12341       Hass Avocados                   1340
# 5785        Organic Reduced Fat 2% Milk     1310
# 27086       Half & Half                     1309
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %%
veinte_principales_articulos.plot(kind='bar',
                                 ylabel='Cantidad de veces que se compran',
                                 xlabel='Producto y ID',
                                 title='Top 20 productos que se ordenan primero')

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los principales 20 articulos que se muestran tienen frecuencias arriba de 1,200 lo que significa que son los favoritos de los clientes por lo cual siempre los ponen primero en sus carritos.

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# El proyecto fue muy fructifero desde el inicio
# - Primero al manejar mucha informacion en 5 archivos diferentes, los cuales contienen muchos renglones y columnas con informacion valiosa sobre lo que esta pasando en la empresa.
# - El primer paso fue analizar cada uno de los archivos para ver duplicados y si realmente son duplicados y porque.
# - Posteriormente fue analizar los valores ausentes, si hay valores ausentes o si no hay y porque, como vimos hubo uno que tiene la misma caracteristica tiene su misma isla y pasillo lo que nos conlleva a un error humano que pudo haber pasado.
# - Una vez que tuvimos los datos limpios y en orden pasamos a la parte del analisis de los datos que es cuando se ve que es lo que realmente esta pasando en la empresa.
# - En la parte A revisamos que los dias y las horas estuvieran de acuerdo a la realidad es decir de 0-23 horas y de 0-6 dias que corresponden a la semana.
# - Posteriormente hicimos analisis en base a los dias en los que se compran mas productos que fueron domingo y lunes el inicio de la semana.
# - Para terminar la parte A tambien revisamos la cantidad de tiempo que esperan las personas para poder volver a pedir siendo esto un dato mayor en los 30 dias y otros datos tambien en 0 dias y cada semana es decir 7-8 dias que es el regreso a los supermercados a comprar comida.
# - En la parte B.
# - Se detecto un patron en lo que son los dias miercoles y sabados que por el medio dia hay un bajon considerable de ventas del dia miercoles (mitad de semana)
# - Se vieron la cantidad de pedidos que hacen los clientes siendo esto la mayor frecuencia 5 o ligeramente un poco mas.
# - Y se vieron por ultimo los top 20 de productos que mas se compran, esto nos da una idea si tuvieras el precio cuanto revenue nos da y poder implementar mas estrategias para que las personas sigan comprando mas productos.
# - En la parte C
# - Se vieron los top 20 articulos que se vuelven a pedir con mayor frecuencia, esto tiene que dar sentido con el analisis de arriba de los top 20 articulos que mas se compran, ya que la recurrencia tambien se ve en los que mas se compran.
#
#  Esto nos da una idea de como esta el negocio,

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda realizar una conclusion general. Esta debe contener todo lo que se hizo en el proyecto de forma enumerada o items.
#
# Desde la carga e importacion, pasando por los cambios realizado (Y el porque de esas decisiones). Agregando lo que se hizo en cada seccion a modo resumen y las conclusiones del  trabajo.
#
# Sirve como resumen de lo realizado en cada proyecto.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, excelente.</div>
